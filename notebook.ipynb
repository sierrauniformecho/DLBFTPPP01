# %%
# Modellbildung: Prognose eines Aktienkurses
# Notebook-Showcase für die IU-Projektpräsentation (Aufgabe 3).

# %%
# %load_ext autoreload
# %autoreload 2

from src.fetch_data import fetch_daily_adjusted
from src.prepare_data import train_test_split, add_lag_feature
from src.model import train_linear_regression, predict
from src.evaluation import mae, rmse
from src.plotting import plot_train_test
